# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress


# Hide warning messages in jupyter notebook(found this on Stack Overflow)
import warnings
warnings.filterwarnings('ignore')

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# View the dataframe
mouse_metadata.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
# Display the dataframe
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single dataset
merged_data = pd.merge(mouse_metadata, study_results, on='Mouse ID')

# Display the merged DF
merged_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the DataFrame.
merged_data['Mouse ID'].nunique()
# Out:
# 249

# %%
# Checking the number of times each mouse appeared in the DataFrame.
merged_data['Mouse ID'].value_counts()
# Out:
# g989    13
# m546    10
# y769    10
# u364    10
# k403    10
#         ..
# x226     1
# l872     1
# u153     1
# o848     1
# n482     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
timepoint_group = merged_data.groupby(['Mouse ID','Timepoint'])

timepoint_group.sum().head(30)
# Out:
#                     Age_months  Weight (g)  Tumor Volume (mm3)  \
# Mouse ID Timepoint
# a203     0                  20          23           45.000000
#          5                  20          23           48.508468
#          10                 20          23           51.852437
#          15                 20          23           52.777870
#          20                 20          23           55.173336
#          25                 20          23           56.793208
#          30                 20          23           59.523197
#          35                 20          23           61.931650
#          40                 20          23           63.593490
#          45                 20          23           67.973419
# a251     0                  21          25           45.000000
#          5                  21          25           46.982127
#          10                 21          25           48.591179
#          15                 21          25           50.534456
# ...

# %%
# # ----------- Trying to understand data ----------------

# mouse_id = merged_data.set_index('Mouse ID')
# mouse = mouse_id.loc['y769', :]
# mouse

# mouse_id = merged_data.set_index('Mouse ID')
# mouse = mouse_id.loc['x226', :]
# mouse

# # --------------------------------------------------------

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mouse_id = merged_data.set_index('Mouse ID')
mouse = mouse_id.loc['g989', :]
mouse
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         20
# g989         Propriva  Female          21          26         25
# g989         Propriva  Female          21          26         30
# g989         Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# mouse_id = merged_data.set_index('Mouse ID')
drop_dupli_mouse = mouse_id.drop('g989')

clean_merged_data = drop_dupli_mouse.reset_index()
clean_merged_data.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
# Checking the number of mice in the clean DataFrame.
clean_merged_data['Mouse ID'].value_counts()
# Out:
# a699    10
# y793    10
# x822    10
# y865    10
# r701    10
#         ..
# u153     1
# d133     1
# b447     1
# f932     1
# l872     1
# Name: Mouse ID, Length: 248, dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, \
# and SEM of the tumor volume for each regimen

# This method is the most straightforward, creating multiple series and putting them all together at the end.

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, \
# and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function.

regimen_group_stats = clean_merged_data.groupby('Drug Regimen').agg\
                        (
                        tumor_vol_Mean = ('Tumor Volume (mm3)', np.mean),
                        tumor_vol_Median = ('Tumor Volume (mm3)', np.median),
                        tumor_vol_Variance = ('Tumor Volume (mm3)', np.var),
                        tumor_vol_StDeviation = ('Tumor Volume (mm3)', np.std),
                        tumor_vol_SEM = ('Tumor Volume (mm3)', st.sem)
                        ).round(2)


regimen_group_stats
# Out:
#               tumor_vol_Mean  tumor_vol_Median  tumor_vol_Variance  \
# Drug Regimen
# Capomulin              40.68             41.56               24.95
# Ceftamin               52.59             51.78               39.29
# Infubinol              52.88             51.82               43.13
# Ketapril               55.24             53.70               68.55
# Naftisol               54.33             52.51               66.17
# Placebo                54.03             52.29               61.17
# Propriva               52.32             50.45               43.85
# Ramicane               40.22             40.67               23.49
# Stelasyn               54.23             52.43               59.45
# Zoniferol              53.24             51.82               48.53
#
#               tumor_vol_StDeviation  tumor_vol_SEM
# Drug Regimen
# Capomulin                      4.99           0.33
# Ceftamin                       6.27           0.47
# ...

# %% [markdown]
# ## Bar Plots

# %%
group = clean_merged_data.groupby(['Drug Regimen', 'Timepoint', 'Mouse ID'])

group_count = pd.DataFrame(group['Mouse ID'].count())
group_count.head(40)
# Out:
#                                  Mouse ID
# Drug Regimen Timepoint Mouse ID
# Capomulin    0         b128             1
#                        b742             1
#                        f966             1
#                        g288             1
#                        g316             1
#                        i557             1
#                        i738             1
#                        j119             1
#                        j246             1
#                        l509             1
#                        l897             1
#                        m601             1
#                        m957             1
#                        r157             1
#                        r554             1
#                        r944             1
#                        s185             1
#                        s710             1
#                        t565             1
#                        u364             1
# ...

# %%
# Create a dataframe grouping by the 'Drug Regimen' column
regimen_group = clean_merged_data.groupby('Drug Regimen')

regimen_group_count = pd.DataFrame(regimen_group['Drug Regimen'].count())

# %%
# Generate a bar plot showing the number of mice per time point \
# for each treatment throughout the course of the study using pandas.


count_chart = regimen_group_count.plot(kind='bar', title="Count of data points for each Drug Regimen", color="turquoise")

count_chart.set_xlabel("Drug Regimen")
count_chart.set_ylabel("Count")

plt.tight_layout()

# Save the figure
plt.savefig("Result_Images/BarChart_Panda.png")

plt.show()

# %%
# Generate a bar plot showing the number of mice per time point \
# for each treatment throughout the course of the study using pyplot.

x_axis = np.arange(len(regimen_group_count))
tick_locations = [value for value in x_axis]


plt.figure(figsize=(7,3.5))
plt.bar(x_axis, regimen_group_count["Drug Regimen"], color='turquoise', align="center", width = 0.5)

plt.xticks(tick_locations, list(regimen_group_count.index), rotation="vertical")


# Set your x and y limits
plt.xlim(-0.65, len(x_axis)-0.35)
plt.ylim(0, max(regimen_group_count["Drug Regimen"])+10)


# Add axis labels and chart title
plt.title("Count of data points for each Drug Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Count")

column_name = ["Drug Regimen"]
plt.legend(column_name,loc="best")


plt.savefig("Result_Images/BarChart_PyPlot.png")

plt.show()

# %% [markdown]
# ## Pie Plots

# %%
# Create a dataframe grouping by the 'Sex' column
gender_group = clean_merged_data.groupby('Sex')


gender_group_count = pd.DataFrame(gender_group['Sex'].count())

# View the groupby dataframe
gender_group_count.head()
# Out:
#         Sex
# Sex
# Female  922
# Male    958

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Generate a pie plot showing the distribution of female versus male mice using pandas

gender_group_count.plot(kind='pie', y='Sex', \
                        title="Distribution of female versus male mice", \
                        colors=["pink", "skyblue"], \
                        shadow=True, \
                        startangle=120, \
                        autopct='%1.1f%%', \
                        legend =False)

plt.axis("equal")

plt.savefig("Result_Images/Panda_PieChart.png")

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

labels = list(gender_group_count.index.values)

piechart_val = gender_group_count['Sex']

colors =["pink", "skyblue"]


plt.pie(piechart_val, labels=labels, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=120)

plt.axis("equal")
plt.title("Distribution of female versus male mice")
plt.ylabel("Sex")

plt.savefig("Result_Images/PyPlot_PieChart.png")

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens.\
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

# Create a list of the four regimens
list_four_regimen = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Slice the cleaned merged data dataframe using the list of four drugs
four_regimens = clean_merged_data[clean_merged_data['Drug Regimen'].isin(list_four_regimen)]


four_regimens.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %%
final_tumor_volume = four_regimens.groupby(['Drug Regimen','Mouse ID']).agg\
                        (final_tumor_size = ('Tumor Volume (mm3)', lambda x: x.iloc[-1])
                        ).round(2)


final_tumor_volume.head()
# Out:
#                        final_tumor_size
# Drug Regimen Mouse ID
# Capomulin    b128                 38.98
#              b742                 38.94
#              f966                 30.49
#              g288                 37.07
#              g316                 40.16

# %%
# Reshape dataframe with Drug Regimen as columns
table_four_regimens = final_tumor_volume.stack(level=0).unstack(level=0)

table_four_regimens.head(10)
# Out:
# Drug Regimen               Capomulin  Ceftamin  Infubinol  Ramicane
# Mouse ID
# a203     final_tumor_size        NaN       NaN      67.97       NaN
# a251     final_tumor_size        NaN       NaN      65.53       NaN
# a275     final_tumor_size        NaN      63.0        NaN       NaN
# a411     final_tumor_size        NaN       NaN        NaN     38.41
# a444     final_tumor_size        NaN       NaN        NaN     43.05
# a520     final_tumor_size        NaN       NaN        NaN     38.81
# a577     final_tumor_size        NaN       NaN      57.03       NaN
# a644     final_tumor_size        NaN       NaN        NaN     32.98
# a685     final_tumor_size        NaN       NaN      66.08       NaN
# b128     final_tumor_size      38.98       NaN        NaN       NaN

# %%
#Calculate the IQR and quantitatively determine if there are any potential outliers.


counter = 0

# quartile calculations for each drug
for drug in list_four_regimen:
    quartiles = table_four_regimens[drug].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = round(upperq-lowerq,2)
    lower_bound = round(lowerq - (1.5*iqr),2)
    upper_bound = round(upperq + (1.5*iqr),2)
    
    # Check if it is the first time through the for loop, if so then print dividing line at top only
    if counter == 0:
        print(f"--------------------------------------------------------")
    print(f"{drug} IQR data is:")
    print(f"The lower quartile of {drug} is: {lowerq}")
    print(f"The upper quartile of {drug} is: {upperq}")
    print(f"The interquartile range of {drug} is: {iqr}")
    print(f"The the median of {drug} is: {quartiles[0.5]} ")
    print(f"Values below {lower_bound} for {drug} could be outliers.")
    print(f"Values above {upper_bound} for {drug} could be outliers.")
    print(f"--------------------------------------------------------")
    counter += 1
# Out:
# --------------------------------------------------------
# Capomulin IQR data is:
# The lower quartile of Capomulin is: 32.38
# The upper quartile of Capomulin is: 40.16
# The interquartile range of Capomulin is: 7.78
# The the median of Capomulin is: 38.13
# Values below 20.71 for Capomulin could be outliers.
# Values above 51.83 for Capomulin could be outliers.
# --------------------------------------------------------
# Ramicane IQR data is:
# The lower quartile of Ramicane is: 31.56
# The upper quartile of Ramicane is: 40.66
# The interquartile range of Ramicane is: 9.1
# The the median of Ramicane is: 36.56
# Values below 17.91 for Ramicane could be outliers.
# Values above 54.31 for Ramicane could be outliers.
# --------------------------------------------------------
# Infubinol IQR data is:
# The lower quartile of Infubinol is: 54.05
# The upper quartile of Infubinol is: 65.53
# The interquartile range of Infubinol is: 11.48
# The the median of Infubinol is: 60.17
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %%
# remove NaN values

boxplot_list = []

for drug in list_four_regimen:
    boxplot_list.append(list(table_four_regimens[drug].dropna()))
    
    

fig1, ax1 = plt.subplots()
ax1.set_title('Final Tumor Volume by Drug Regimen')
ax1.set_xlabel('Drug Regimen')
ax1.set_ylabel('Tumor Volume (mm3)')
ax1.boxplot(boxplot_list)


plt.xticks([1,2,3,4], list_four_regimen)

plt.savefig("Result_Images/BoxWhiskerPlot.png")

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Create a dataframe for Capomulin data
capomulin_data = clean_merged_data.loc[clean_merged_data['Drug Regimen'] == 'Capomulin']

capomulin_data.head()
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
#
#     Tumor Volume (mm3)  Metastatic Sites
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0

# %%
# Groupby timepoint and then get the mean of the tumor volume and 


capo_tp_tumor = capomulin_data.groupby(['Timepoint']).agg(TumorVolume_Mean=('Tumor Volume (mm3)', np.mean)).round(2)

 
capo_tp_tumor.head(10)
# Out:
#            TumorVolume_Mean
# Timepoint
# 0                     45.00
# 5                     44.27
# 10                    43.08
# 15                    42.06
# 20                    40.72
# 25                    39.94
# 30                    38.77
# 35                    37.82
# 40                    36.96
# 45                    36.24

# %%
# Plot a line plot 

x_time_points = list(capo_tp_tumor.index.values)
y_tumor_vol = capo_tp_tumor['TumorVolume_Mean']

plt.plot(x_time_points, y_tumor_vol, linewidth=1, marker="o", color="blue")
         

# Add the title, x labels and y labels
plt.title("Time Point vs. Tumor Volume for Capomulin")
plt.xlabel("Time (days)")
plt.ylabel("Tumor Volume (mm3)")

# Set x and y limits 
plt.xlim(min(x_time_points)-3, max(x_time_points)+3)
plt.ylim(min(y_tumor_vol)-3, max(y_tumor_vol)+3)

plt.savefig("Result_Images/LineChart.png")

plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %%
# capomulin_data.head()

# Groupby Mouse ID using .agg() method and get the weight and mean of tumor volume
capo_mouse_id = capomulin_data.groupby(['Mouse ID']).agg\
                (Mouse_Weight = ('Weight (g)', np.mean),\
                 Tumor_Vol_Mean = ('Tumor Volume (mm3)', np.mean)\
                ).round(2)

capo_mouse_id.head(15)
# Out:
#           Mouse_Weight  Tumor_Vol_Mean
# Mouse ID
# b128                22           41.96
# b742                21           40.08
# f966                17           36.51
# g288                19           41.99
# g316                22           44.61
# i557                24           44.81
# i738                20           39.14
# j119                23           44.47
# j246                21           43.22
# l509                21           44.43
# l897                19           42.51
# m601                17           34.85
# m957                19           39.05
# r157                25           45.80
# r554                17           36.51

# %%
#create scatter plot from the above dataframe
x_values = capo_mouse_id['Mouse_Weight']
y_values = capo_mouse_id['Tumor_Vol_Mean']


plt.scatter(x_values, y_values,\
            marker='s',
            facecolors='orange',
            edgecolors='red',
            s=capo_mouse_id['Tumor_Vol_Mean'],
            alpha=1)


plt.title("Mouse Weight vs. Average Tumor Volume")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Tumor Volume (mm3)")

plt.savefig("Result_Images/weightVStumorVol_ScatterChart.png")

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

# %%
correlation = st.pearsonr(capo_mouse_id['Mouse_Weight'], capo_mouse_id['Tumor_Vol_Mean'])

print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.84

# %%
x_values = capo_mouse_id['Mouse_Weight']
y_values = capo_mouse_id['Tumor_Vol_Mean']


(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
line_eq = f'y = {str(round(slope,2))}x + {str(round(intercept,2))}'


plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(17,37),fontsize=15,color="r")

plt.title("Mouse weight vs. Avg. Tumor Volume")
plt.xlabel("Mouse weight (g)")
plt.ylabel("Tumor Volume (mm3)")

print(f"The r-squared is: {rvalue}")
print(f"The equation of the regression line is: {line_eq}")

plt.savefig("Result_Images/Scatter_Regression_weightVStumorVol.png")

plt.show()
# Out:
# The r-squared is: 0.8418558779004007
# The equation of the regression line is: y = 0.95x + 21.56
